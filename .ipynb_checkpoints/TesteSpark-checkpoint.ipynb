# %%
from pyspark.sql.types import *
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.15.34:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[2]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
csvFile = spark.read.csv('/Users/eduardoaandrad/Dropbox/Desenv/Script/csv/kc_house_data.csv',header=True, inferSchema=True)
# csvFile.write.saveAsTable("kc_house_data")

# %%
csvFile.show()
# Out:
# +----------+--------+---------+--------+---------+-----------+--------+------+----------+----+---------+-----+----------+-------------+--------+------------+-------+-------+--------+-------------+----------+
# |        id| dt_date|    price|bedrooms|bathrooms|sqft_living|sqft_lot|floors|waterfront|view|condition|grade|sqft_above|sqft_basement|yr_built|yr_renovated|zipcode|    lat|    long|sqft_living15|sqft_lot15|
# +----------+--------+---------+--------+---------+-----------+--------+------+----------+----+---------+-----+----------+-------------+--------+------------+-------+-------+--------+-------------+----------+
# |7129300520|20141013| 221900.0|       3|      1.0|       1180|    5650|   1.0|         0|   0|        3|    7|      1180|            0|    1955|           0|  98178|47.5112|-122.257|         1340|      5650|
# ...

# %%
csvFile.select('sqft_living','dt_date').show()
# Out:
# +-----------+--------+
# |sqft_living| dt_date|
# +-----------+--------+
# |       1180|20141013|
# |       2570|20141209|
# |        770|20150225|
# |       1960|20141209|
# |       1680|20150218|
# |       5420|20140512|
# |       1715|20140627|
# |       1060|20150115|
# |       1780|20150415|
# |       1890|20150312|
# |       3560|20150403|
# |       1160|20140527|
# |       1430|20140528|
# |       1370|20141007|
# |       1810|20150312|
# |       2950|20150124|
# |       1890|20140731|
# |       1600|20140529|
# |       1200|20141205|
# |       1250|20150424|
# +-----------+--------+
# only showing top 20 rows

# %%
csvFile.createOrReplaceTempView("people")

# %%
sqlDF = spark.sql("SELECT * FROM people")

# %%
sqlDF.show()
# Out:
# +----------+--------+---------+--------+---------+-----------+--------+------+----------+----+---------+-----+----------+-------------+--------+------------+-------+-------+--------+-------------+----------+
# |        id| dt_date|    price|bedrooms|bathrooms|sqft_living|sqft_lot|floors|waterfront|view|condition|grade|sqft_above|sqft_basement|yr_built|yr_renovated|zipcode|    lat|    long|sqft_living15|sqft_lot15|
# +----------+--------+---------+--------+---------+-----------+--------+------+----------+----+---------+-----+----------+-------------+--------+------------+-------+-------+--------+-------------+----------+
# |7129300520|20141013| 221900.0|       3|      1.0|       1180|    5650|   1.0|         0|   0|        3|    7|      1180|            0|    1955|           0|  98178|47.5112|-122.257|         1340|      5650|
# ...
